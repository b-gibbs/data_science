# %% [markdown]
# # What is the True Normal Human Body Temperature?

# %% [markdown]
# #### Background
#
# The mean normal body temperature was held to be 37$^{\circ}$C or 98.6$^{\circ}$F for more than 120 years since it was first conceptualized and reported by Carl Wunderlich in a famous 1868 book. But, is this value statistically correct?

# %% [markdown]
# <h3>Exercises</h3>
#
# <p>In this exercise, you will analyze a dataset of human body temperatures and employ the concepts of hypothesis testing, confidence intervals, and statistical significance.</p>
#
# <p>Answer the following questions <b>in this notebook below and submit to your Github account</b>.</p>
#
# <ol>
# <li>  Is the distribution of body temperatures normal?
#     <ul>
#     <li> Although this is not a requirement for the Central Limit Theorem to hold (read the introduction on Wikipedia's page about the CLT carefully: https://en.wikipedia.org/wiki/Central_limit_theorem), it gives us some peace of mind that the population may also be normally distributed if we assume that this sample is representative of the population.
#     <li> Think about the way you're going to check for the normality of the distribution. Graphical methods are usually used first, but there are also other ways: https://en.wikipedia.org/wiki/Normality_test
#     </ul>
# <li>  Is the sample size large? Are the observations independent?
#     <ul>
#     <li> Remember that this is a condition for the Central Limit Theorem, and hence the statistical tests we are using, to apply.
#     </ul>
# <li>  Is the true population mean really 98.6 degrees F?
#     <ul>
#     <li> First, try a bootstrap hypothesis test.
#     <li> Now, let's try frequentist statistical testing. Would you use a one-sample or two-sample test? Why?
#     <li> In this situation, is it appropriate to use the $t$ or $z$ statistic?
#     <li> Now try using the other test. How is the result be different? Why?
#     </ul>
# <li>  Draw a small sample of size 10 from the data and repeat both frequentist tests.
#     <ul>
#     <li> Which one is the correct one to use?
#     <li> What do you notice? What does this tell you about the difference in application of the $t$ and $z$ statistic?
#     </ul>
# <li>  At what temperature should we consider someone's temperature to be "abnormal"?
#     <ul>
#     <li> As in the previous example, try calculating everything using the boostrap approach, as well as the frequentist approach.
#     <li> Start by computing the margin of error and confidence interval. When calculating the confidence interval, keep in mind that you should use the appropriate formula for one draw, and not N draws.
#     </ul>
# <li>  Is there a significant difference between males and females in normal temperature?
#     <ul>
#     <li> What testing approach did you use and why?
#     <li> Write a story with your conclusion in the context of the original problem.
#     </ul>
# </ol>
#
# You can include written notes in notebook cells using Markdown:
#    - In the control panel at the top, choose Cell > Cell Type > Markdown
#    - Markdown syntax: http://nestacms.com/docs/creating-content/markdown-cheat-sheet
#
# #### Resources
#
# + Information and data sources: http://www.amstat.org/publications/jse/datasets/normtemp.txt, http://www.amstat.org/publications/jse/jse_data_archive.htm
# + Markdown syntax: http://nestacms.com/docs/creating-content/markdown-cheat-sheet
#
# ****

# %% [markdown]
# ## Summary of Findings
# ***
# The mean normal body temperature was held to be 98.6°F for more than 120 years since it was first conceptualized and reported by Carl Wunderlich in a famous 1868 book.  After examining a data set of 130 samples (65 males and 65 females), we'll see that the mean normal body temperature is actually 98.25°F.  We'll also see that the mean body temperature of females is significantly higher than males'.

# %%
# IMPORTS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.stats as smd
import pylab

# matplotlib setup
# %matplotlib inline

# turn edges on in plt
plt.rcParams["patch.force_edgecolor"] = True

np.random.seed(42)

df = pd.read_csv('data/human_body_temperature.csv')
df.head()
# Out:
#    temperature gender  heart_rate
# 0         99.3      F        68.0
# 1         98.4      F        81.0
# 2         97.8      M        73.0
# 3         99.2      F        66.0
# 4         98.0      F        73.0

# %%
# FUNCTIONS USED

def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x: sort the data
    x = np.sort(data)

    # y: range for y-axis
    y = np.arange(1, n+1) / n

    return x, y

# %% [markdown]
# ### Question #1
# ***
# Is the distribution of body temperatures normal?
# <ul>
#     <li>Although this is not a requirement for the Central Limit Theorem to hold (read the introduction on Wikipedia's page about the CLT carefully: https://en.wikipedia.org/wiki/Central_limit_theorem), it gives us some peace of mind that the population may also be normally distributed if we assume that this sample is representative of the population.</br>
#     <li>Think about the way you're going to check for the normality of the distribution. Graphical methods are usually used first, but there are also other ways: https://en.wikipedia.org/wiki/Normality_test
# </ul>

# %%
# Plot a histogram to see whether the distribution is normal
temp = df.temperature

sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

# Number of bins is the square root of number of data points: n_bins
n_bins = np.sqrt(len(temp))

# Convert number of bins to integer: n_bins
n_bins = int(n_bins)

# plot hist
_ = plt.hist(temp, normed=True, bins=n_bins)

# overlay PDF of the Standard Normal Distribution
x = np.linspace(np.min(temp) - 1, np.max(temp) + 1, 100, endpoint=True)
pdf = [stats.norm.pdf(_, loc=np.mean(temp), scale=np.std(temp)) for _ in x]
plt.plot(x, pdf, 'k-')


# labels
_ = plt.text(95.5, 0.5, r'$\mu= {},\ \sigma={}$'.format(round(np.mean(temp), 2), round(np.std(temp), 2)))
_ = plt.xlabel('Temperature (F)')
_ = plt.ylabel('Frequency')
_ = plt.title('Fig. 1.1: Human Body Temperatures')

margins = 0.02
_ = plt.legend(('Std Normal Dist', 'Samples'))
plt.ylim(-0.01, 0.65)
plt.show();

# %%
sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

stats.probplot(temp, dist='norm', plot=pylab)
plt.title('Fig. 1.2: Probability Plot of Human Body Temperatures');

# %%
sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

# Plot the CDFs
x, y = ecdf(temp)

# draw 100,000 random samples from a normal distribution
nm_temp = np.random.normal(np.mean(temp), np.std(temp), 100000)
nm_x, nm_y = ecdf(nm_temp)

_ = plt.plot(x, y, marker='.', linestyle='none')
_ = plt.plot(nm_x, nm_y)

_ = plt.xlabel('Temperature (F)')
_ = plt.ylabel('CDF')
_ = plt.title('Fig. 1.3: Cumulative Distribution Function - Human Body Temperatures')
margins = 0.02

plt.show();

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h4>Analysis:</h4>  The histogram (Fig. 1.1) shows that the sample's distribution is unimodal and essentially symmetrical about the mean.  Looking at the sample distribution in a QQ plot (Fig.1.2) and the CDF (Fig. 1.3), we see that the frequency distribution of the data is very close to normal, although the QQ plot and the CDF both show some variation and a couple of outliers on both tails.
# </div>

# %% [markdown]
# ### Question #2
# ***
# Is the sample size large? Are the observations independent?
#  - Remember that this is a condition for the Central Limit Theorem, and hence the statistical tests we are using, to apply.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 3 columns):
# temperature    130 non-null float64
# gender         130 non-null object
# heart_rate     130 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h4>Analysis:</h4>  <p>It is generally accepted that if data is symmetric about the mean and unimodal, 30 samples are enough for the Central Limit Theorem to apply.  The 130 observations we have is a tiny fraction of the population of all humans, but, as shown in the analysis of Question #1, our data is symmetric about the mean and essentially unimodal, so the Central Limit Theorem is applicable.  </p>
#
# <p>For the observations to be independent it would mean that knowing the outcome of one sample would provide us with no information about another sample.  In this case, knowing one person's body temperature gives us no information about any other measured body temperature.  Gender or heart rate may have an effect on body temperature.  The effects of gender on mean body temperature are explored below.  </p>
# </div>

# %% [markdown]
# ### Question #3
# ***
# Is the true population mean really 98.6 degrees F?
# <ol>
#     <li> First, try a bootstrap hypothesis test.
#     <li> Now, let's try frequentist statistical testing. Would you use a one-sample or two-sample test? Why?
#     <li> In this situation, is it appropriate to use the $t$ or $z$ statistic?
#     <li> Now try using the other test. How is the result be different? Why?
# </ol>

# %% [markdown]
# <h4>Hypotheses:</h4>
# $H_0:\  \bar x =$ 98.6°
# $H_a:\  \bar x \neq$ 98.6°

# %%
df.describe()
# Out:
#        temperature  heart_rate
# count   130.000000  130.000000
# mean     98.249231   73.761538
# std       0.733183    7.062077
# min      96.300000   57.000000
# 25%      97.800000   69.000000
# 50%      98.300000   74.000000
# 75%      98.700000   79.000000
# max     100.800000   89.000000

# %% [markdown]
# #### 3.1 bootstrap hypothesis test - 100,000 samples

# %%
# bootstrap hypothesis test with 100,000 samples
bs_replicates = np.empty(100000)

size = len(bs_replicates)

for i in range(size):
    bs_sample = np.random.choice(temp, len(temp))
    bs_replicates[i] = np.mean(bs_sample)
    
p = np.sum(bs_replicates >= 98.6) / size

print('p-value: ', p)
print('mean: ', np.mean(bs_replicates))
# Out:
# p-value:  0.0
# mean:  98.24910042307691

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h4>Analysis:</h4>  Through 100,000 bootstrap samples we arrive at a p-value of 0.0, indicating that our null hypothesis should be rejected.  The mean body temperature of our sample set is 98.25°.
# </div>

# %% [markdown]
# #### 3.2 frequentist statistical testing
# Now, let's try frequentist statistical testing. Would you use a one-sample or two-sample test? Why?

# %% [markdown]
# <div class="alert alert-block alert-success"><h4>Analysis:</h4> We are comparing the mean of a single sample to 98.6° to determine whether there is a statistically-significant difference.  This is a classic use case for a one-sample test.  A two-sample test is used to determine if two population means are equal, commonly used to test if a new process or treatment is superior to a current process or treatment.
# </div>

# %% [markdown]
# #### 3.3 / 3.4 $t$- or $Z$- statistic?

# %% [markdown]
# In this situation, is it appropriate to use the $t$- or $Z$-statistic?
# Now try using the other test. How is the result different? Why?

# %%
z_score = (np.mean(temp) - 98.6) / (np.std(temp) / np.sqrt(len(temp)))

p_value = stats.norm.sf(abs(z_score))*2
print('Z-score: {}\np-value: {}\n'.format(round(z_score, 5), round(p_value, 5)))

t_stat = stats.ttest_1samp(temp, 98.6)
print('t-score: {}\np-value: {}'.format(round(t_stat.statistic, 5), round(t_stat.pvalue, 5)))
# Out:
# Z-score: -5.47593
# p-value: 0.0
#
# t-score: -5.45482
# p-value: 0.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h4>Analysis:</h4> <p>The $t$-statistic is typically reserved for sample sizes less than 30 ($n$ < 30), when the sample distribution is symmetric about the mean and unimodal.  As the sample size increases above 30, the $t$-distribution begins to look increasingly like the $Z$-distribution.  Given our sample size of 130 and the fact that our distribution is more-or-less symmetrical about the mean and unimodal, the $Z$-statistic is the better choice.  </p>
# <p>We use a two-tailed test since our mean could be either greater or less than 98.6°.  Both the $t-$ and $Z-$ statistics have small enough p-values to make them significant.  </p>
# <p>For a 95% confidence interval, the z*-value is 1.96, meaning our z-score must be within 1.96 standard errors from the hypothesized mean of 98.6.  Both methods show that the mean of the sample is more than five standard deviations less than 98.6°.  We can safely reject the null hypothesis.  </p>
# <p>The $t$- and $Z$-scores are very similar, because, as noted, as the number of samples increases above 30, the $t$-distribution increasingly resembles the $Z$-distribution.</p>
# </div>

# %% [markdown]
# ### Question #4
# ***
# Draw a small sample of size 10 from the data and repeat both frequentist tests.
# <ul>
#     <li> Which one is the correct one to use?
#     <li> What do you notice? What does this tell you about the difference in application of the $t$ and $z$ statistic?
#     </ul>

# %% [markdown]
# #### $t$-score

# %%
sample_temp = np.random.choice(a = temp, size=10)

# %%
r = stats.ttest_1samp(sample_temp, 98.6)
print('t-score: {}\np-value: '.format(round(r.statistic, 5)), round(r.pvalue, 5))
# Out:
# t-score: -1.54598
# p-value:  0.15651

# %% [markdown]
# #### $Z$-score

# %%
z_score = (np.mean(sample_temp) - 98.6) / (np.std(sample_temp) / np.sqrt(len(sample_temp)))

p_value = stats.norm.sf(abs(z_score)) * 2

print('Z-score: {}\np-value: {}'.format((round(z_score, 5)), round(p_value, 5)))
# Out:
# Z-score: -1.6296
# p-value: 0.10319

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h4>Analysis:</h4> In this case, since $n$ < 30, best practices indicate we should use the $t$-score.
# However, the p-values of both the $t$-score and $Z$-score are well above the 0.05 typically required for statistical significance.  While p-value alone shouldn't be determinative, it is a useful metric in situations where you want to know whether a model result that appears interesting and useful is within the range of normal chance variability.
# Taking into consideration the results we got with larger sample sizes, I'd say these results indicate that we need a larger sample size before we can make any determination on the value of these scores.
# </div>

# %% [markdown]
# ### Question #5
# ***
# At what temperature should we consider someone's temperature to be "abnormal"?
# <ul>
#     <li> As in the previous example, try calculating everything using the boostrap approach, as well as the frequentist approach.
#     <li> Start by computing the margin of error and confidence interval. When calculating the confidence interval, keep in mind that you should use the appropriate formula for one draw, and not N draws.
# </ul>

# %%
mu = np.mean(temp)
sigma = np.std(temp)
print('mu: {}\nsigma: {}\n'.format(round(mu, 3), round(sigma, 3)))

# z*-value
z_critical = stats.norm.ppf(q = 0.975)              

# margin of error 
margin_of_error = z_critical * sigma
print('z*-value: {}\nmargin of error: {}\n'.format(round(z_critical, 3), round(margin_of_error, 3))) 

# confidence interval for one draw
ci_low, ci_high = stats.norm.interval(0.95, loc=mu, scale=sigma)
print('95% confidence interval (one draw): {} - {}'.format(round(ci_low, 3), round(ci_high, 3)))
# Out:
# mu: 98.249
# sigma: 0.73
#
# z*-value: 1.96
# margin of error: 1.431
#
# 95% confidence interval (one draw): 96.818 - 99.681

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h4>Analysis:</h4>  Using the mean we calculated (98.249°), and at a 95% confidence interval, a temperature below 96.8° or above 99.7° would be considered abnormal.
# </div>

# %% [markdown]
# ### Question #6
# ***
# Is there a significant difference between males and females in normal temperature?
# <ul>
#     <li> What testing approach did you use and why?
#     <li> Write a story with your conclusion in the context of the original problem.
# </ul>

# %% [markdown]
# ### Hypotheses
# $H_0: \mu_m\ =\ \mu_f$
#
# $H_a: \mu_m \neq\ \mu_f$

# %%
males = df[df.gender == 'M']
females = df[df.gender == 'F']

print('Of the {} participants, {} are female and {} are male.'.format(len(males + females), len(females), len(males)))
# Out:
# Of the 130 participants, 65 are female and 65 are male.

# %%
# plot a boxplot for an overview
sns.boxplot(x = 'gender', y = 'temperature', data=df)

sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

_ = plt.xlabel('Gender')
_ = plt.ylabel('Temp')
_ = plt.title('Fig. 6.1: Body Temp by Gender')

plt.show();

# %%
# are both samples normally distributed?
sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

# Compute the ECDFs for males and females
x_male, y_male = ecdf(males.temperature)
x_female, y_female = ecdf(females.temperature)

# Generate plot
plt.plot(x_male, y_male, marker = '.', linestyle = 'none', color='b')
plt.plot(x_female, y_female, marker='.', linestyle='none', color='r')

# draw 100,000 random samples from a normal distribution
m_norm_dist = np.random.normal(np.mean(males.temperature), np.std(males.temperature), 100000)
mnd_x, mnd_y = ecdf(m_norm_dist)
_ = plt.plot(mnd_x, mnd_y, color='b', alpha=0.5)

# draw 100,000 random samples from a normal distribution
f_norm_dist = np.random.normal(np.mean(females.temperature), np.std(females.temperature), 100000)
fnd_x, fnd_y = ecdf(f_norm_dist)
_ = plt.plot(fnd_x, fnd_y, color='r', alpha=0.5)

# Make the margins nice
plt.margins = 0.02

# Label the axes
_ = plt.xlabel('Gender')
_ = plt.ylabel('ECDF')
_ = plt.title('Fig. 6.2: CDFs of males v. females')
_ = plt.legend(('males', 'females'), loc='lower right', fontsize='large', markerscale=2)

plt.show();

# %%
# common variables
temp_m = males.temperature
temp_f = females.temperature

# %%
# Check for identical variances
mv = np.var(temp_m)
fv = np.var(temp_f)

print('Male variance: {}\nFemale variance: {}'.format(mv, fv))
# Out:
# Male variance: 0.4807479289940825
# Female variance: 0.5442698224852062

# %%
# Variances are not identical, so set `equal_var` to false to perform Welch's t-test
r = stats.ttest_ind(temp_m, temp_f, equal_var=False)
print('t-score: {}\np-value: {}'.format(str(r.statistic), str(r.pvalue)))
# Out:
# t-score: -2.285434538165611
# p-value: 0.023938264182934196

# %%
# z*-value
z_critical = stats.norm.ppf(q = 0.975)              

# males
print('MALES')
mu_m = np.mean(temp_m)
sigma_m = np.std(temp_m)
print('mu: {}\nsigma: {}\n'.format(round(mu_m, 3), round(sigma_m, 3)))

m_err_m = z_critical * sigma_m
print('z*-value: {}\nmargin of error: {}\n'.format(round(z_critical, 3), round(m_err_m, 3))) 

# confidence interval for one draw
ci_low_m, ci_high_m = stats.norm.interval(0.95, loc=mu_m, scale=sigma_m)
print('95% confidence interval (one draw): {} - {}'.format(round(ci_low_m, 3), round(ci_high_m, 3)))

# females
print('\n\nFEMALES')
mu_f = np.mean(temp_f)
sigma_f = np.std(temp_f)
print('mu: {}\nsigma: {}\n'.format(round(mu_f, 3), round(sigma_f, 3)))

m_err_f = z_critical * sigma_f
print('z*-value: {}\nmargin of error: {}\n'.format(round(z_critical, 3), round(m_err_f, 3))) 

# confidence interval for one draw
ci_low_f, ci_high_f = stats.norm.interval(0.95, loc=mu_f, scale=sigma_f)
print('95% confidence interval (one draw): {} - {}'.format(round(ci_low_f, 3), round(ci_high_f, 3)))
# Out:
# MALES
# mu: 98.105
# sigma: 0.693
#
# z*-value: 1.96
# margin of error: 1.359
#
# 95% confidence interval (one draw): 96.746 - 99.464
#
#
# FEMALES
# mu: 98.394
# sigma: 0.738
#
# z*-value: 1.96
# margin of error: 1.446
#
# 95% confidence interval (one draw): 96.948 - 99.84

# %%
# bootstrap hypothesis test - males
bs_replicates_m = np.empty(100000)

size_m = len(bs_replicates_m)

for i in range(size):
    bs_sample_m = np.random.choice(temp_m, len(temp_m))
    bs_replicates_m[i] = np.mean(bs_sample_m)
    
p_value_m = np.sum(bs_replicates_m >= 98.6) / size_m

print('p-value: {}\nmean: {}'.format(p_value_m, np.mean(bs_replicates_m)))
# Out:
# p-value: 0.0
# mean: 98.10486976923079

# %%
# bootstrap hypothesis test - females
bs_replicates_f = np.empty(100000)

size_f = len(bs_replicates_f)

for i in range(size):
    bs_sample_f = np.random.choice(temp_f, len(temp_f))
    bs_replicates_f[i] = np.mean(bs_sample_f)
    
p_value_f = np.sum(bs_replicates_f >= 98.6) / size

print('p-value: {}\nmean: {}'.format(p_value_f, np.mean(bs_replicates_f)))
# Out:
# p-value: 0.01291
# mean: 98.39364513846154

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h4>Analysis:</h4>  <p>We've already seen that the mean human body temperature is actually 98.25°, rather than 98.6°.  Now, let's look to see whether gender has an effect on mean body temperature.</p>
#
# <p>In order to determine whether there is a statistically-significant difference between the normal body temperatures of men and women, we start with an overview of the data, which consists of 130 samples; 65 male and 65 female.</p>
#
# <p>A boxplot (Fig. 6.1) shows that the females' mean body temperature is slightly higher than the males'.</p>
#
# <p>CDFs (Fig. 6.2) show that both sample sets roughly follow the standard normal distribution, with the females' temperatures running a little warmer and with slightly more variation.  Because the distributions for both samples approximate the standard normal distribution, the Central Limit Theorem applies and we can use $t$- and $Z$-tests.  Because both sample sizes are also larger than 30, the $Z$-test should be used.  We'll take a look at the results of a $t$-test, anyway.</p>
#
# <p>Because we're comparing means of two different populations, we use a two-sided test for the null hypothesis that two independent samples have identical means.  The p-value for this test (0.0239) is less than 0.05, we reject the null hypothesis of equal means.</p>
#
# <p>The $Z$-tests and bootstrap hypothesis tests support the results of the $t$-test.  A table summarizing the differences between male and female mean body temperatures is provided below:</p>
#
# <table>
# <thead>
# <tr>
# <th></th>
# <th>Male</th>
# <th>Female</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>$\mu$</td>
# <td>98.105</td>
# <td>98.394</td>
# </tr>
# <tr>
# <td>$\sigma$</td>
# <td>0.693</td>
# <td>0.738</td>
# </tr>
# <tr>
# <td>z*-value</td>
# <td>1.96</td>
# <td>1.96</td>
# </tr>
# <tr>
# <td>Margin of Error</td>
# <td>1.359</td>
# <td>1.446</td>
# </tr>
# <tr>
# <td>95% Conf. Int.</td>
# <td>96.746 - 99.464</td>
# <td>96.948 - 99.84</td>
# </tr>
# </tbody></table>
#
# </div>
